# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# STEP 1: READING DATA
#STEP 2: PERFORM EDA/PREPROCESSING
#STEP 3: TRAIN/TEST SPLIT
#STEP 4: TRAIN MODEL
#STEP 5: TEST MODEL PERFORMANCE

# %%
df=pd.read_csv("C:\\Users\\rautu\\OneDrive\\Desktop\\data folder\\weatherHistory.csv")

# %%
df.describe() #shows that the column Loud Cover is filled with 'zero'
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
sns.countplot(data=df,x='Precip Type')
# Out:
# <Axes: xlabel='Precip Type', ylabel='count'>

# %%
df['Formatted Date']=pd.to_datetime(df['Formatted Date'],utc=True)

# %%
df[df['Precip Type']=='snow']
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 1562  2006-12-13 01:00:00+00:00          Foggy        snow        -0.483333
# 1563  2006-12-13 02:00:00+00:00          Foggy        snow        -0.483333
# 1564  2006-12-13 03:00:00+00:00          Foggy        snow        -0.922222
# 1565  2006-12-13 04:00:00+00:00          Foggy        snow        -1.038889
# 1566  2006-12-13 05:00:00+00:00          Foggy        snow        -1.088889
# ...                         ...            ...         ...              ...
# 93265 2016-03-28 03:00:00+00:00          Foggy        snow        -0.783333
# 93266 2016-03-28 04:00:00+00:00          Foggy        snow        -1.111111
# 93267 2016-03-28 05:00:00+00:00          Foggy        snow        -1.044444
# 93311 2016-03-03 02:00:00+00:00  Partly Cloudy        snow        -0.511111
# 93506 2016-03-09 05:00:00+00:00          Foggy        snow        -0.027778
#
# ...

# %%
df['Formatted Date']
# Out:
# 0       2006-03-31 22:00:00+00:00
# 1       2006-03-31 23:00:00+00:00
# 2       2006-04-01 00:00:00+00:00
# 3       2006-04-01 01:00:00+00:00
# 4       2006-04-01 02:00:00+00:00
#                    ...
# 96448   2016-09-09 17:00:00+00:00
# 96449   2016-09-09 18:00:00+00:00
# 96450   2016-09-09 19:00:00+00:00
# 96451   2016-09-09 20:00:00+00:00
# 96452   2016-09-09 21:00:00+00:00
# Name: Formatted Date, Length: 96453, dtype: datetime64[ns, UTC]

# %%
df['Daily Summary'].value_counts()
# Out:
# Daily Summary
# Mostly cloudy throughout the day.                                                                       20085
# Partly cloudy throughout the day.                                                                        9981
# Partly cloudy until night.                                                                               6169
# Partly cloudy starting in the morning.                                                                   5184
# Foggy in the morning.                                                                                    4201
#                                                                                                         ...
# Breezy starting overnight continuing until morning and foggy overnight.                                    24
# Mostly cloudy throughout the day and breezy starting overnight continuing until afternoon.                 24
# ...

# %%
df[['Summary','Daily Summary','Precip Type']]
# Out:
#              Summary                           Daily Summary Precip Type
# 0      Partly Cloudy       Partly cloudy throughout the day.        rain
# 1      Partly Cloudy       Partly cloudy throughout the day.        rain
# 2      Mostly Cloudy       Partly cloudy throughout the day.        rain
# 3      Partly Cloudy       Partly cloudy throughout the day.        rain
# 4      Mostly Cloudy       Partly cloudy throughout the day.        rain
# ...              ...                                     ...         ...
# 96448  Partly Cloudy  Partly cloudy starting in the morning.        rain
# 96449  Partly Cloudy  Partly cloudy starting in the morning.        rain
# 96450  Partly Cloudy  Partly cloudy starting in the morning.        rain
# 96451  Partly Cloudy  Partly cloudy starting in the morning.        rain
# 96452  Partly Cloudy  Partly cloudy starting in the morning.        rain
#
# [96453 rows x 3 columns]

# %%
df[df['Precip Type']!='rain'][['Summary','Daily Summary','Precip Type']] #shows some nan
# Out:
#              Summary                             Daily Summary Precip Type
# 1562           Foggy                 Foggy throughout the day.        snow
# 1563           Foggy                 Foggy throughout the day.        snow
# 1564           Foggy                 Foggy throughout the day.        snow
# 1565           Foggy                 Foggy throughout the day.        snow
# 1566           Foggy                 Foggy throughout the day.        snow
# ...              ...                                       ...         ...
# 95584  Mostly Cloudy  Mostly cloudy starting in the afternoon.         NaN
# 95585  Mostly Cloudy  Mostly cloudy starting in the afternoon.         NaN
# 95586  Mostly Cloudy  Mostly cloudy starting in the afternoon.         NaN
# 95587  Partly Cloudy  Mostly cloudy starting in the afternoon.         NaN
# 95588  Mostly Cloudy  Mostly cloudy starting in the afternoon.         NaN
#
# [11229 rows x 3 columns]

# %%
df['Loud Cover'].value_counts()
# Out:
# Loud Cover
# 0.0    96453
# Name: count, dtype: int64

# %%
df.groupby(df['Formatted Date'])['Precip Type'].unique()
# Out:
# Formatted Date
# 2005-12-31 23:00:00+00:00    [rain]
# 2006-01-01 00:00:00+00:00    [rain]
# 2006-01-01 01:00:00+00:00    [rain]
# 2006-01-01 02:00:00+00:00    [rain]
# 2006-01-01 03:00:00+00:00    [rain]
#                               ...
# 2016-12-31 18:00:00+00:00    [rain]
# 2016-12-31 19:00:00+00:00    [rain]
# 2016-12-31 20:00:00+00:00    [snow]
# 2016-12-31 21:00:00+00:00    [snow]
# 2016-12-31 22:00:00+00:00    [snow]
# Name: Precip Type, Length: 96429, dtype: object

# %%
df['Formatted Date'].dt.year.unique()
# Out:
# array([2006, 2005, 2010, 2007, 2008, 2009, 2011, 2012, 2013, 2014, 2015,
#        2016])

# %%
#it simply looks like the 'DAILY SUMMARY'&'SUMMARY' columns have same meaning.
#later we will confirm it with correlation check

# %%
df['Year']=df['Formatted Date'].dt.year

# %%
df['Month']=df['Formatted Date'].dt.month #since month could be a predictor for weather

# %%
df['day']=df['Formatted Date'].dt.day

# %%
df['time']=df['Formatted Date'].dt.hour

# %%
df['Precip Type'] = df['Precip Type'].replace(['NaN', 'nan', ' ', ''], np.nan)
df['Precip Type']=df['Precip Type'].fillna('clear') #filling nan with clear

# %%
df[df['Precip Type']!='rain'][['Summary','Daily Summary','Precip Type']]
# Out:
#              Summary                             Daily Summary Precip Type
# 1562           Foggy                 Foggy throughout the day.        snow
# 1563           Foggy                 Foggy throughout the day.        snow
# 1564           Foggy                 Foggy throughout the day.        snow
# 1565           Foggy                 Foggy throughout the day.        snow
# 1566           Foggy                 Foggy throughout the day.        snow
# ...              ...                                       ...         ...
# 95584  Mostly Cloudy  Mostly cloudy starting in the afternoon.       clear
# 95585  Mostly Cloudy  Mostly cloudy starting in the afternoon.       clear
# 95586  Mostly Cloudy  Mostly cloudy starting in the afternoon.       clear
# 95587  Partly Cloudy  Mostly cloudy starting in the afternoon.       clear
# 95588  Mostly Cloudy  Mostly cloudy starting in the afternoon.       clear
#
# [11229 rows x 3 columns]

# %%
#it simply looks like the 'DAILY SUMMARY'&'SUMMARY' columns have same meaning.
#later we will make a combine list of the columns that have no impact on target and drop them.

# %%
df['Precip Type'].unique()
# Out:
# array(['rain', 'snow', 'clear'], dtype=object)

# %%
#now we are going to assign 'PRECIP TYPE' column with either 'Rain' or 'No rain'

# %%
map={'rain':'rain','snow':'no_rain','clear':'no_rain'}

# %%
df['Precip Type'].map(map)
# Out:
# 0        rain
# 1        rain
# 2        rain
# 3        rain
# 4        rain
#          ...
# 96448    rain
# 96449    rain
# 96450    rain
# 96451    rain
# 96452    rain
# Name: Precip Type, Length: 96453, dtype: object

# %%
df['Precip Type']=df['Precip Type'].map(map)

# %%
#again replacing those rain,no_rain text with binary values
df['Precip_Type_int']=df['Precip Type'].map({'rain':0,'no_rain':1})

# %%
df['Precip_Type_int'].value_counts()
# Out:
# Precip_Type_int
# 0    85224
# 1    11229
# Name: count, dtype: int64

# %%
df['Summary'].value_counts()
# Out:
# Summary
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
#doing quick correlation check between the numeric features

# %%
corr=df.corr(numeric_only=True)[['Precip_Type_int']][1:].sort_values(by='Precip_Type_int',ascending=False)

# %%
corr
# Out:
#                           Precip_Type_int
# Precip_Type_int                  1.000000
# Humidity                         0.228314
# day                              0.018632
# Pressure (millibars)             0.011103
# Year                            -0.024660
# Wind Bearing (degrees)          -0.041406
# time                            -0.049256
# Wind Speed (km/h)               -0.063988
# Month                           -0.133773
# Visibility (km)                 -0.317667
# Apparent Temperature (C)        -0.555889
# Loud Cover                            NaN

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=corr.transpose())
plt.xticks(rotation=90);

# %%
#column Loud cover has no relationship with target.
#since we have made three datetime columns from original datetime columns, so we will drop it as well
# in the following query we will drop them.

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary', 'Year', 'Month', 'day', 'time',
#        'Precip_Type_int'],
#       dtype='object')

# %%
df=df.drop(['Loud Cover','Formatted Date','Daily Summary'],axis=1)

# %%
df.columns
# Out:
# Index(['Summary', 'Precip Type', 'Temperature (C)', 'Apparent Temperature (C)',
#        'Humidity', 'Wind Speed (km/h)', 'Wind Bearing (degrees)',
#        'Visibility (km)', 'Pressure (millibars)', 'Year', 'Month', 'day',
#        'time', 'Precip_Type_int'],
#       dtype='object')

# %%
sns.histplot(data=df,x='Humidity',hue='Precip Type',kde=True)
# Out:
# <Axes: xlabel='Humidity', ylabel='Count'>

# %%
sns.boxplot(data=df,x='Precip Type') #outliers in precip type
# Out:
# <Axes: xlabel='Precip Type'>

# %%
df['Humidity'].value_counts()
# Out:
# Humidity
# 0.93    5708
# 0.92    3888
# 0.96    3843
# 1.00    2890
# 0.89    2837
#         ...
# 0.15      10
# 0.16       8
# 0.14       4
# 0.13       1
# 0.12       1
# Name: count, Length: 90, dtype: int64

# %%
df.groupby('Precip Type')['Humidity'].apply(lambda x:(x<0.5).sum())
# Out:
# Precip Type
# no_rain      116
# rain       14608
# Name: Humidity, dtype: int64

# %%
#since we have imbalanced target, i have decided to keep the outliers present in '0' class

# %%
df['Summary'].nunique()
# Out:
# 27

# %%
df['Summary']=df['Summary'].str.lower().str.strip()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.pipeline import Pipeline

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay

# %%
X=df.drop(['Precip Type','Precip_Type_int'],axis=1)
y=df['Precip Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42,stratify=y)

# %%
#now we will build a funtion that consists a pipeline for preprocessing and evaluating the model model for prediction.

# %%
#to initiate the columns for ColumnTransformer
cat_cols=X_train.select_dtypes(include='object').columns
num_cols=X_train.select_dtypes(include='number').columns

# %%
def func(model,X_train,y_train,X_test,y_test,cat_cols,num_cols):
    
    pipe=Pipeline(steps=[('transformer',ColumnTransformer(transformers=[('encoder',OneHotEncoder(handle_unknown='ignore'),cat_cols),
                                                                       ('scaler',StandardScaler(),num_cols)])),
                        ('my_model',model)])
    pipe.fit(X_train,y_train)
    pred=pipe.predict(X_test)
    print(classification_report(y_test,pred))
    cm=ConfusionMatrixDisplay(confusion_matrix(y_test,pred))
    cm.plot()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.linear_model import LogisticRegression

# %%
random_model=RandomForestClassifier(class_weight='balanced')

# %%
df.head()
# Out:
#          Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0  partly cloudy        rain         9.472222                  7.388889
# 1  partly cloudy        rain         9.355556                  7.227778
# 2  mostly cloudy        rain         9.377778                  9.377778
# 3  partly cloudy        rain         8.288889                  5.944444
# 4  mostly cloudy        rain         8.755556                  6.977778
#
#    Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 0      0.89            14.1197                   251.0          15.8263
# 1      0.86            14.2646                   259.0          15.8263
# 2      0.89             3.9284                   204.0          14.9569
# 3      0.83            14.1036                   269.0          15.8263
# 4      0.83            11.0446                   259.0          15.8263
#
#    Pressure (millibars)  Year  Month  day  time  Precip_Type_int
# ...

# %%
func(model=random_model,
     X_train=X_train,
     y_train=y_train,
     X_test=X_test,
     y_test=y_test,
     cat_cols=cat_cols,
     num_cols=num_cols)
# Out:
#               precision    recall  f1-score   support
#
#      no_rain       1.00      0.98      0.99      3706
#         rain       1.00      1.00      1.00     28124
#
#     accuracy                           1.00     31830
#    macro avg       1.00      0.99      0.99     31830
# weighted avg       1.00      1.00      1.00     31830

# %%
logistic_model=LogisticRegression(class_weight='balanced')

# %%
func(model=logistic_model,
     X_train=X_train,
     y_train=y_train,
     X_test=X_test,
     y_test=y_test,
     cat_cols=cat_cols,
     num_cols=num_cols)
# Out:
#               precision    recall  f1-score   support
#
#      no_rain       0.60      0.95      0.73      3706
#         rain       0.99      0.91      0.95     28124
#
#     accuracy                           0.92     31830
#    macro avg       0.79      0.93      0.84     31830
# weighted avg       0.95      0.92      0.93     31830

# %%
decision_model=DecisionTreeClassifier()

# %%
func(model=decision_model,
     X_train=X_train,
     y_train=y_train,
     X_test=X_test,
     y_test=y_test,
     cat_cols=cat_cols,
     num_cols=num_cols)
# Out:
#               precision    recall  f1-score   support
#
#      no_rain       0.99      0.99      0.99      3706
#         rain       1.00      1.00      1.00     28124
#
#     accuracy                           1.00     31830
#    macro avg       1.00      1.00      1.00     31830
# weighted avg       1.00      1.00      1.00     31830

# %%
pipe=Pipeline(steps=[('transformer',ColumnTransformer(transformers=[('encoder',OneHotEncoder(handle_unknown='ignore'),cat_cols),
                                                                       ('scaler',StandardScaler(),num_cols)])),
                        ('my_model',RandomForestClassifier(class_weight='balanced'))])
pipe.fit(X,y)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Summary'], dtype='object')),
#                                                  ('scaler', StandardScaler(),
#                                                   Index(['Temperature (C)', 'Apparent Temperature (C)', 'Humidity',
#        'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)',
#        'Pressure (millibars)', 'Year', 'Month', 'day', 'time'],
#       dtype='object'))])),
#                 ('my_model', RandomForestClassifier(class_weight='balanced'))])

# %%
from joblib import dump,load

# %%
dump(pipe,'rain_model.pkl')
# Out:
# ['rain_model.pkl']

# %%
dump(X_train.columns.to_list(),'weather_columns.pkl')
# Out:
# ['weather_columns.pkl']

# %%
X_train.columns.to_list()
# Out:
# ['Summary',
#  'Temperature (C)',
#  'Apparent Temperature (C)',
#  'Humidity',
#  'Wind Speed (km/h)',
#  'Wind Bearing (degrees)',
#  'Visibility (km)',
#  'Pressure (millibars)',
#  'Year',
#  'Month',
#  'day',
#  'time']

# %%
load('rain_model.pkl')
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Summary'], dtype='object')),
#                                                  ('scaler', StandardScaler(),
#                                                   Index(['Temperature (C)', 'Apparent Temperature (C)', 'Humidity',
#        'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)',
#        'Pressure (millibars)', 'Year', 'Month', 'day', 'time'],
#       dtype='object'))])),
#                 ('my_model', RandomForestClassifier(class_weight='balanced'))])
